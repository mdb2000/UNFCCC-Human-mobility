# %% [markdown]
# <a href="https://colab.research.google.com/github/mdb2000/UNFCCC-Human-mobility/blob/Python-codes/BERTopic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bertopic import BERTopic
import re
from langdetect import detect
import numpy as np
import pandas as pd
from umap import UMAP
import matplotlib
import matplotlib.pyplot as plt

# %%
# Load data
df = pd.read_csv('C:\\Users\\3104470\\Desktop\\output\\sentences datasets\\df_final.csv')

# %%
# Initialize and fit the BERTopic model on the processed column of the dataset
topic_model = BERTopic(nr_topics=80)
topics, probs = topic_model.fit_transform(df['processed'].tolist())

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                    Name  \
# 0      -1   2626      -1_risk_adaptation_disaster_impact
# 1       0    129  0_migrant_remittance_sending_household
# 2       1    121             1_un_entity_disaster_relate
# 3       2    108        2_relocation_plan_community_move
# 4       3    100       3_tool_guidance_technical_support
# ..    ...    ...                                     ...
# 75     74     12               74_woman_gender_man_women
# 76     75     11      75_knowledge_lack_actionable_datum
# 77     76     11     76_sudan_sanction_sector_irrigation
# 78     77     11         77_minimize_category_fall_avoid
# 79     78     10             78_loss_niger_life_heritage
#
#                                        Representation  \
# 0   [risk, adaptation, disaster, impact, address, ...
# 1   [migrant, remittance, sending, household, city...
# 2   [un, entity, disaster, relate, strategic, with...
# 3   [relocation, plan, community, move, carry, rel...
# 4   [tool, guidance, technical, support, collabora...
# ..                                                ...
# 75  [woman, gender, man, women, farm, male, female...
# 76  [knowledge, lack, actionable, datum, exist, co...
# 77  [sudan, sanction, sector, irrigation, plan, na...
# 78  [minimize, category, fall, avoid, blurring, mi...
# 79  [loss, niger, life, heritage, degradation, ter...
#
#                                   Representative_Docs
# 0   [['task', 'force', 'encourage', 'executive', '...
# 1   [['contact', 'ms', 'associate', 'coordinator',...
# 2   [['seek', 'align', 'measure', 'avert', 'minimi...
# 3   [['planned', 'relocation', 'may', 'carry', 'in...
# 4   [['see', 'nap', 'publication', 'activity', 'mo...
# ..                                                ...
# 75  [['restricted', 'scholarship', 'development', ...
# 76  [['furthermore', 'issue', 'cut', 'across', 'po...
# 77  [['pasture', 'legislation', 'sudan', 'national...
# 78  [['seek', 'avoid', 'occurrence', 'loss', 'dama...
# 79  [['example', 'loss', 'damage', 'associate', 'd...
#
# [80 rows x 5 columns]

# %%
# Get the topic information as a DataFrame
topic_info = topic_model.get_topic_info()

# Save the DataFrame as a CSV file
csv_file_path = 'C:\\Users\\3104470\\Desktop\\output\\sentences datasets\\images\\BERTopic_info.csv'
topic_info.to_csv(csv_file_path, index=False)

# %%
topic_model.visualize_barchart(top_n_topics = 12, n_words = 8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 topic_model.visualize_barchart(top_n_topics = 12, n_words = 8)
#
# NameError: name 'topic_model' is not defined

# %%
topic_model.get_document_info(df['processed'].tolist())
# Out:
#                                                Document  Topic  \
# 0     ['information', 'gather', 'apply', 'understand...     -1
# 1     ['many', 'tool', 'idea', 'use', 'seasonal', 'c...     -1
# 2     ['participation', 'indigenous', 'people', 'rep...     -1
# 3     ['final', 'informal', 'consultation', 'agree',...     18
# 4     ['advance', 'unedited', 'version', 'decision',...     18
# ...                                                 ...    ...
# 5423  ['panelist', 'government', 'minister', 'secret...     -1
# 5424  ['population', 'million', 'united', 'states', ...     35
# 5425  ['emission', 'sector', 'energy', 'use', 'resid...     14
# 5426  ['energy', 'consumption', 'sector', 'account',...     -1
# 5427  ['addition', 'united', 'states', 'department',...     -1
#
#                                        Name  \
# 0        -1_risk_adaptation_disaster_impact
# 1        -1_risk_adaptation_disaster_impact
# 2        -1_risk_adaptation_disaster_impact
# 3     18_right_indigenous_empowerment_party
# 4     18_right_indigenous_empowerment_party
# ...                                     ...
# 5423     -1_risk_adaptation_disaster_impact
# 5424   35_population_immigration_birth_rate
# 5425        14_energy_fuel_fossil_renewable
# 5426     -1_risk_adaptation_disaster_impact
# 5427     -1_risk_adaptation_disaster_impact
#
#                                          Representation  \
# 0     [risk, adaptation, disaster, impact, address, ...
# 1     [risk, adaptation, disaster, impact, address, ...
# 2     [risk, adaptation, disaster, impact, address, ...
# 3     [right, indigenous, empowerment, party, obliga...
# 4     [right, indigenous, empowerment, party, obliga...
# ...                                                 ...
# 5423  [risk, adaptation, disaster, impact, address, ...
# 5424  [population, immigration, birth, rate, million...
# 5425  [energy, fuel, fossil, renewable, carbon, elec...
# 5426  [risk, adaptation, disaster, impact, address, ...
# 5427  [risk, adaptation, disaster, impact, address, ...
#
#                                     Representative_Docs  \
# 0     [['task', 'force', 'encourage', 'executive', '...
# 1     [['task', 'force', 'encourage', 'executive', '...
# 2     [['task', 'force', 'encourage', 'executive', '...
# 3     [['complaint', 'address', 'description', 'coop...
# 4     [['complaint', 'address', 'description', 'coop...
# ...                                                 ...
# 5423  [['task', 'force', 'encourage', 'executive', '...
# 5424  [['demography', 'sweden', 'slight', 'growth', ...
# 5425  [['transmission', 'distribution', 'system', 't...
# 5426  [['task', 'force', 'encourage', 'executive', '...
# 5427  [['task', 'force', 'encourage', 'executive', '...
#
#                                             Top_n_words  Probability  \
# 0     risk - adaptation - disaster - impact - addres...     0.000000
# 1     risk - adaptation - disaster - impact - addres...     0.000000
# 2     risk - adaptation - disaster - impact - addres...     0.000000
# 3     right - indigenous - empowerment - party - obl...     1.000000
# 4     right - indigenous - empowerment - party - obl...     0.970461
# ...                                                 ...          ...
# 5423  risk - adaptation - disaster - impact - addres...     0.000000
# 5424  population - immigration - birth - rate - mill...     0.887989
# 5425  energy - fuel - fossil - renewable - carbon - ...     0.402229
# 5426  risk - adaptation - disaster - impact - addres...     0.000000
# 5427  risk - adaptation - disaster - impact - addres...     0.000000
#
#       Representative_document
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 5423                    False
# 5424                    False
# 5425                    False
# 5426                    False
# 5427                    False
#
# [5428 rows x 8 columns]

# %%
topic_model.visualize_heatmap()

# %%
hierarchical_topics = topic_model.hierarchical_topics(df['processed'].tolist())
topic_model.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 78/78 [00:00<00:00, 167.01it/s]

# %%
#display in line in jupyter lab
# %matplotlib inline

# Prepare data for plotting
embeddings = topic_model._extract_embeddings(df['processed'], method="document")
umap_model = UMAP(n_neighbors=10, n_components=2, min_dist=0.0, metric='cosine').fit(embeddings)
df_umap = pd.DataFrame(umap_model.embedding_, columns=["x", "y"])
df_umap["topic"] = topics

# Plot parameters
top_n = 15
fontsize = 12

# %%
# Slice data
to_plot = df_umap.copy()
to_plot.loc[to_plot.topic >= top_n, 'topic'] = -1
outliers = to_plot[to_plot.topic == -1]
non_outliers = to_plot[to_plot.topic != -1]
#this part of code considers only the first 10 topics, and consider outliers the others, assigning them with a index -1

# Visualize topics
cmap = matplotlib.colors.ListedColormap(['#FF5722', # Red
                                         '#03A9F4', # Blue
                                         '#4CAF50', # Green
                                         '#80CBC4', # FFEB3B
                                         '#673AB7', # Purple
                                         '#795548', # Brown
                                         '#E91E63', # Pink
                                         '#212121', # Black
                                         '#00BCD4', # Light Blue
                                         '#CDDC39', # Yellow/Red
                                         '#AED581', # Light Green
                                         '#FFE082', # Light Orange
                                         '#BCAAA4', # Light Brown
                                         '#B39DDB', # Light Purple
                                         '#F48FB1', # Light Pink
                                         ])

# %%
# Visualize outliers + inliers
fig, ax = plt.subplots(figsize=(15, 15))
scatter_outliers = ax.scatter(outliers['x'], outliers['y'], c="#808080", s=3, alpha=.3)
scatter = ax.scatter(non_outliers['x'], non_outliers['y'], c=non_outliers['topic'], s=4, alpha=.3, cmap=cmap)

# Add topic names to clusters
centroids = to_plot.groupby("topic").mean().reset_index().iloc[1:]
for row in centroids.iterrows():
    topic = int(row[1]['topic'])
    topic_words = topic_model.get_topic(topic)
    if topic_words:
        text = f"{topic}: " + "_".join([x[0] for x in topic_words[:3]])
        ax.text(row[1]['x'], row[1]['y']*1.01, text, fontsize=fontsize, horizontalalignment='center')

ax.text(0.99, 0.01, f"BERTopic - Top {top_n} topics", transform=ax.transAxes, horizontalalignment="right", color="black")
plt.xticks([], [])
plt.yticks([], [])
plt.savefig("C:\\Users\\3104470\\Desktop\\output\\sentences datasets\\images\\BERTopic_Example_Cluster_Plot.png")
plt.show()

# %%
topic_info.to_csv('C:\\Users\\3104470\\Desktop\\output\\sentences datasets\\long version filtered eng&duplicates\\Adaptation_BERTopics_topics2.csv', index=False)

# %%
topic_model.visualize_topics()
